# %% [markdown]
# GitHub Repository: https://github.com/kgreeley/Web-Scraping-Project

# %% [markdown]
# This is the code behind the project.
#
# All the loading of the csv files after scraping are towards the bottom.
#
# ## As I worked on the project, I worked up from the bottom of the file towards the top.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
S78.sort_values('Fouls PG', ascending = False)
# Out:
#                               Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Ivano Pezzuto                           1     46.00          1.77        0.00
# Gianluca Aureliano                      3     36.67          0.98        0.00
# Davide Ghersini                         1     35.00          0.81        1.00
# Luigi Nasca                             1     33.00          1.22        0.00
# Alberto Undiano Mallenco               20     31.55          0.91        0.10
# Patrick Ittrich                        13     31.38          0.87        0.31
# Tobias Welz                             3     31.33          0.85        0.33
# Mario Melero López                     19     31.32          0.86        0.21
# Dr. Robert Kampka                      12     31.17          0.81        0.33
# Tobias Stieler                         17     31.12          0.81        0.35
# Francesco Fourneau                      1     31.00          1.07        0.00
# ...

# %%
final = pd.read_csv('Ref Statistics.csv')
final
# Out:
#                                     Name  Appearances  Fouls PG  Fouls/Tackle  \
# 0                   Santiago Jaime Latre           21     28.71          0.80
# 1            José María Sánchez Martínez           21     27.33          0.73
# 2            José Luis González González           21     25.14          0.64
# 3                  Javier Alberola Rojas           21     25.14          0.69
# 4           Ricardo de Burgos Bengoetxea           20     26.55          0.73
# 5            Ignacio Iglesias Villanueva           20     27.90          0.74
# 6               Alberto Undiano Mallenco           20     31.55          0.91
# 7                Carlos del Cerro Grande           19     26.58          0.72
# 8                      Jesús Gil Manzano           19     28.37          0.74
# 9                  Juan Martínez Munuera           19     29.00          0.78
# 10                    Mario Melero López           19     31.32          0.86
# ...

# %%
sns.heatmap(FPT)

# %%
S78.loc[S78['Appearances'] > 20]
# Out:
#                              Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Santiago Jaime Latre                  21     28.71          0.80        0.43
# José María Sánchez Martínez           21     27.33          0.73        0.38
# José Luis González González           21     25.14          0.64        0.33
# Javier Alberola Rojas                 21     25.14          0.69        0.33
# François Letexier                     24     26.38          0.72        0.42
# Mikael Lesage                         23     23.83          0.63        0.09
# Antony Gautier                        23     28.78          0.82        0.26
# Benoît Bastien                        22     27.73          0.82        0.41
# Jerome Brisard                        22     27.23          0.75        0.45
# Ruddy Buquet                          22     28.32          0.77        0.36
# Benoît Millot                         22     25.91          0.71        0.36
# ...

# %%
S78.loc[S78['Fouls PG'] > 28]
# Out:
#                               Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Santiago Jaime Latre                   21     28.71          0.80        0.43
# Alberto Undiano Mallenco               20     31.55          0.91        0.10
# Jesús Gil Manzano                      19     28.37          0.74        0.42
# Juan Martínez Munuera                  19     29.00          0.78        0.26
# Mario Melero López                     19     31.32          0.86        0.21
# Daniel Jesús Trujillo Suárez           19     28.89          0.79        0.32
# Pablo González Fuertes                 19     28.37          0.86        0.32
# Javier Estrada Fernández               18     30.44          0.89        0.28
# Deniz Aytekin                          17     29.53          0.77        0.47
# Tobias Stieler                         17     31.12          0.81        0.35
# Daniel Siebert                         17     28.41          0.75        0.24
# ...

# %%
mfpg = {'League':['Bundesliga', 'LaLiga','Ligue 1', 'Premier League','Serie A'],
        '09/10':[2.7, 2.8, 2.7, 3.4, 2.6],
       '10/11':[3.2, 3.1, 2.8, 3.7, 2.9],
       '11/12':[2.8, 3.1, 2.9, 4.1, 2.9],
       '12/13':[2.8, 3.2, 3.2, 4.0, 2.9],
       '13/14':[2.9, 3.3, 3.3, 4.1, 3.2],
       '14/15':[3.0, 3.2, 3.3, 4.1, 3.0],
       '15/16':[3.1, 3.3, 3.4, 4.0, 3.0],
       '16/17':[3.1, 3.2, 3.5, 4.0, 3.2],
       '17/18':[3.2, 3.2, 3.5, 4.2, 3.4]}

Minutes_FPG = pd.DataFrame(mfpg)
Minutes_FPG.set_index('League', inplace = True)
Minutes_FPG
# Out:
#                 09/10  10/11  11/12  12/13  13/14  14/15  15/16  16/17  17/18
# League
# Bundesliga        2.7    3.2    2.8    2.8    2.9    3.0    3.1    3.1    3.2
# LaLiga            2.8    3.1    3.1    3.2    3.3    3.2    3.3    3.2    3.2
# Ligue 1           2.7    2.8    2.9    3.2    3.3    3.3    3.4    3.5    3.5
# Premier League    3.4    3.7    4.1    4.0    4.1    4.1    4.0    4.0    4.2
# Serie A           2.6    2.9    2.9    2.9    3.2    3.0    3.0    3.2    3.4

# %%
x = ['9/10','10/11','11/12','12/13','13/14','14/15','15/16','16/17','17/18']
B = Minutes_FPG.loc['Bundesliga', :]
LL = Minutes_FPG.loc['LaLiga', :]
L1 = Minutes_FPG.loc['Ligue 1', :]
PL = Minutes_FPG.loc['Premier League', :]
SA = Minutes_FPG.loc['Serie A', :]

plt.plot(x, B, '.-', color = 'orange', markersize = 15, linewidth = 2, alpha = 0.5, label = 'Bundesliga',)
plt.plot(x, LL,'.-', color = 'red', markersize = 15, linewidth = 2, alpha = 0.5, label = 'LaLiga')
plt.plot(x, L1,'.-', color = 'blue', markersize = 15, linewidth = 2, alpha = 0.5, label = 'Ligue 1')
plt.plot(x, PL,'.-', color = 'yellow', markersize = 15, linewidth = 2, alpha = 0.7, label = 'Premier')
plt.plot(x, SA,'.-', color = 'green', markersize = 15, linewidth = 2, alpha = 0.5, label = 'Serie A')

plt.title('Minutes Per Fouls By Season')
plt.xlabel('Season')
plt.ylabel('Minutes Per Foul')

plt.legend(loc=2)

# %%
round(B09['Fouls/Tackle'].mean(),2)
# Out:
# 0.8

# %%
round(LL91['Fouls/Tackle'].mean(),2)
# Out:
# 0.8

# %%
round(L90['Fouls/Tackle'].mean(),2)
# Out:
# 0.78

# %%
round(PL90['Fouls/Tackle'].mean(),2)
# Out:
# 0.62

# %%
round(SA09['Fouls/Tackle'].mean(),2)
# Out:
# 0.84

# %%
fpt = {'League':['Bundesliga', 'LaLiga','Ligue 1', 'Premier League','Serie A'],
        '09/10':[0.8, 0.8, 0.78, 0.62, 0.84],
       '10/11':[0.72, 0.71, 0.81, 0.61, 0.78],
       '11/12':[0.71, 0.64, 0.81, 0.59, 0.72],
       '12/13':[0.69, 0.66, 0.75, 0.6, 0.71],
       '13/14':[0.74, 0.68, 0.72, 0.58, 0.74],
       '14/15':[0.77, 0.71, 0.68, 0.57, 0.88],
       '15/16':[0.83, 0.7, 0.67, 0.6, 0.88],
       '16/17':[0.79, 0.71, 0.69, 0.67, 0.86],
       '17/18':[0.7, 0.8, 0.71, 0.64, 0.82]}

FPT = pd.DataFrame(fpt)
FPT.set_index('League', inplace = True)
FPT
# Out:
#                 09/10  10/11  11/12  12/13  13/14  14/15  15/16  16/17  17/18
# League
# Bundesliga       0.80   0.72   0.71   0.69   0.74   0.77   0.83   0.79   0.70
# LaLiga           0.80   0.71   0.64   0.66   0.68   0.71   0.70   0.71   0.80
# Ligue 1          0.78   0.81   0.81   0.75   0.72   0.68   0.67   0.69   0.71
# Premier League   0.62   0.61   0.59   0.60   0.58   0.57   0.60   0.67   0.64
# Serie A          0.84   0.78   0.72   0.71   0.74   0.88   0.88   0.86   0.82

# %%
FPT.loc['Serie A'].mean()*100
# Out:
# 80.33333333333333

# %%
sns.boxplot(x = 'League', y = '17/18', data = FPT)

# %%
round(LL78['Fouls/Tackle'].mean(),2)
# Out:
# 0.77

# %%
round(90/(LL91['Fouls PG']).mean(), 1)
# Out:
# 2.8

# %%
round(90/(L90['Fouls PG']).mean(), 1)
# Out:
# 2.7

# %%
round(90/(PL90['Fouls PG']).mean(), 1)
# Out:
# 3.4

# %%
round(90/(SA09['Fouls PG']).mean(), 1)
# Out:
# 2.6

# %%
'''The Average Time Without a Foul From All Leagues during 17/18 season'''
round(90/(S78['Fouls PG']).mean(), 2)
# Out:
# 3.47

# %%
S78.to_csv('Season78.csv')

# %%
import seaborn as sns
sns.distplot(S78['Fouls/Tackle'], bins = 10, vertical = True)

# %%
sns.lmplot("Fouls PG", "Appearances", LL78)

# %%
def group_by(dataframe):
    df = dataframe
    name = df.groupby('Name')
    for key, item in name:
        print(key)
        print('-'*70)
        print(item)
        print('\n')

# %%
f1 = pd.concat([LL_78, LL_67])
f1
f2 = pd.concat([f1,LL_56])
f2
f3 = pd.concat([LL_45,LL_34,LL_23,LL_12,LL_11,LL_91])
f3.set_index('Name', inplace = True)
name = f3.groupby('Name')
for key, item in name:
    print(key)
    print('-'*70)
    print(item)
    print('\n')

# %%
L1 = pd.concat([L78,L67,L56,L45,L34,L23,L12,L11,L90])
L1.set_index('Name', inplace = True)
L1

# %%
p1 = pd.concat([PL78,PL67,PL_56,PL45,PL34,PL23,PL12,PL90])
p1.set_index('Name', inplace = True)
p1

# %%
s1 = pd.concat([SA78,SA67,SA56,SA45,SA34,SA23,SA12,SA11,SA09])
s1.set_index('Name', inplace = True)
s1

# %%
f1 = pd.concat([LL78, LL67])
f1
f2 = pd.concat([f1,LL56])
f2
LaLiga = pd.concat([f2,LL45,LL34,LL23,LL12,LL11,LL91])
LaLiga
Leagues = pd.concat([LaLiga, B78,B67,B56,B45,B34,B23,B12,B11,B09,L78,L67,L56,L45,L34,L23,L12,L11,L90,PL78,PL67,PL56,PL45,PL34,PL23,PL12,PL90,SA78,SA67,SA56,SA45,SA34,SA23,SA12,SA11,SA09])
Leagues

# %%
Leagues[['Fouls PG']].mean()

# %%
game = Leagues.groupby(['League', 'Name'])
for key, item in game:
    print(key)
    print('-'*70)
    print(item)
    print('\n')

# %%
Leagues['Minutes Per Foul'] = round(90/(Leagues['Fouls PG']),2)

# %%
Leagues

# %%
Leagues.to_csv('Ref Statistics.csv')

# %%
Leagues.groupby('League')

# %%
group_by(Leagues)

# %%
some = Leagues[['Fouls PG', 'League', 'Season']]
some

# %%
Leagues['Minutes Per Foul'].mean()

# %%
Leagues['Compare MPF to Mean'] = round(Leagues['Minutes Per Foul'].mean(),1)

# %%
Leagues

# %%
S78 = pd.concat([LL78, B78, L78, PL78,SA78])
S78
# Out:
#                                     Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Santiago Jaime Latre                         21     28.71          0.80
# José María Sánchez Martínez                  21     27.33          0.73
# José Luis González González                  21     25.14          0.64
# Javier Alberola Rojas                        21     25.14          0.69
# Ricardo de Burgos Bengoetxea                 20     26.55          0.73
# Ignacio Iglesias Villanueva                  20     27.90          0.74
# Alberto Undiano Mallenco                     20     31.55          0.91
# Carlos del Cerro Grande                      19     26.58          0.72
# Jesús Gil Manzano                            19     28.37          0.74
# Juan Martínez Munuera                        19     29.00          0.78
# Mario Melero López                           19     31.32          0.86
# José Luis Munuera Montero                    19     26.84          0.78
# ...

# %%
S78['Minutes Per Foul'] = round(90/(S78['Fouls PG']), 1)
S78
# Out:
#                                     Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Santiago Jaime Latre                         21     28.71          0.80
# José María Sánchez Martínez                  21     27.33          0.73
# José Luis González González                  21     25.14          0.64
# Javier Alberola Rojas                        21     25.14          0.69
# Ricardo de Burgos Bengoetxea                 20     26.55          0.73
# Ignacio Iglesias Villanueva                  20     27.90          0.74
# Alberto Undiano Mallenco                     20     31.55          0.91
# Carlos del Cerro Grande                      19     26.58          0.72
# Jesús Gil Manzano                            19     28.37          0.74
# Juan Martínez Munuera                        19     29.00          0.78
# Mario Melero López                           19     31.32          0.86
# José Luis Munuera Montero                    19     26.84          0.78
# ...

# %%
def pull(dataframe):
    '''This should return the AVG Fouls Per Game for that season. Do check the DataFrame; .iloc will depend on
    the rank. This function will return the value of the seasons with 21 rows.'''
    df = dataframe
    return df.loc['Total/Average', 'Fouls PG']

# %%
FPG.to_csv('FPG.csv')

# %%
data = {'League':['Bundesliga', 'LaLiga','Ligue 1', 'Premier League','Serie A'],
        '09/10':[33.95, 31.72, 32.50, 26.28, 35.46],
       '10/11':[32.71, 29.28, 31.91, 24.25, 30.99],
       '11/12':[32.42, 29.39, 31.41, 21.86, 30.53],
       '12/13':[31.57, 28.45, 28.13, 22.53, 30.58],
       '13/14':[30.77, 27.24, 27.44, 21.68, 29.55],
       '14/15':[28.43, 28.43, 27.50, 22.68, 30.41],
       '15/16':[29.16, 27.28, 26.75, 21.57, 30.41],
       '16/17':[28.65, 27.96, 25.08, 22.76, 28.01],
       '17/18':[27.83, 27.71, 26.19, 20.71, 25.56]}
FPG = pd.DataFrame(data)
FPG.set_index('League', inplace = True)
FPG
# Out:
#                 09/10  10/11  11/12  12/13  13/14  14/15  15/16  16/17  17/18
# League
# Bundesliga      33.95  32.71  32.42  31.57  30.77  28.43  29.16  28.65  27.83
# LaLiga          31.72  29.28  29.39  28.45  27.24  28.43  27.28  27.96  27.71
# Ligue 1         32.50  31.91  31.41  28.13  27.44  27.50  26.75  25.08  26.19
# Premier League  26.28  24.25  21.86  22.53  21.68  22.68  21.57  22.76  20.71
# Serie A         35.46  30.99  30.53  30.58  29.55  30.41  30.41  28.01  25.56

# %%
sns.heatmap(FPG)

# %%
x = ['9/10','10/11','11/12','12/13','13/14','14/15','15/16','16/17','17/18']
B = FPG.loc['Bundesliga', :]
LL = FPG.loc['LaLiga', :]
L1 = FPG.loc['Ligue 1', :]
PL = FPG.loc['Premier League', :]
SA = FPG.loc['Serie A', :]

plt.plot(x, B, '.-', color = 'orange', markersize = 15, linewidth = 2, alpha = 0.5, label = 'Bundesliga',)
plt.plot(x, LL,'.-', color = 'red', markersize = 15, linewidth = 2, alpha = 0.5, label = 'LaLiga')
plt.plot(x, L1,'.-', color = 'blue', markersize = 15, linewidth = 2, alpha = 0.5, label = 'Ligue 1')
plt.plot(x, PL,'.-', color = 'yellow', markersize = 15, linewidth = 2, alpha = 0.7, label = 'Premier')
plt.plot(x, SA,'.-', color = 'green', markersize = 15, linewidth = 2, alpha = 0.5, label = 'Serie A')

plt.title('Fouls Per Game By League')
plt.xlabel('Season')
plt.ylabel('Fouls Per Game')

plt.legend(loc=1)

# %%
LL_78 = pd.read_csv('LaLiga_17_18.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_78.set_index('Rank', inplace = True)
LL78 = LL_78[LL_78.Name != 'Total / Average']
LL78.set_index('Name', inplace = True)
LL78['League'] = 'LaLiga'
LL78['Season'] = '17/18'
LL78
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                     Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Santiago Jaime Latre                         21     28.71          0.80
# José María Sánchez Martínez                  21     27.33          0.73
# José Luis González González                  21     25.14          0.64
# ...

# %%
LL_67 = pd.read_csv('LaLiga_16_17.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_67.set_index('Rank', inplace = True)
LL67 = LL_67[LL_67.Name != 'Total / Average']
LL67.set_index('Name', inplace = True)
LL67['League'] = 'LaLiga'
LL67['Season'] = '16/17'
LL67
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                     Appearances  Fouls PG  Fouls/Tackle  \
# Name
# José Luis González González                  23     29.96          0.78
# Juan Martínez Munuera                        22     27.91          0.73
# José María Sánchez Martínez                  21     26.95          0.69
# ...

# %%
LL_56 = pd.read_csv('LaLiga_15_16.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_56.set_index('Rank', inplace = True)
LL56 = LL_56[LL_56.Name != 'Total / Average']
LL56.set_index('Name', inplace = True)
LL56['League'] = 'LaLiga'
LL56['Season'] = '15/16'
LL56
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                     Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Alberto Undiano Mallenco                     22     27.27          0.71
# Carlos Clos Gómez                            21     27.57          0.68
# José Luis González González                  21     26.19          0.68
# ...

# %%
LL_45 = pd.read_csv('LaLiga_14_15.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_45.set_index('Rank', inplace = True)
LL45 = LL_45[LL_45.Name != 'Total / Average']
LL45.set_index('Name', inplace = True)
LL45['League'] = 'LaLiga'
LL45['Season'] = '14/15'
LL45
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                     Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Eduardo Prieto Iglesias                      21     29.38          0.92
# Iñaki Vicandi Garrido                        21     35.10          0.87
# Alejandro José Hernández Hernández           21     27.05          0.66
# ...

# %%
LL_34 = pd.read_csv('LaLiga_13_14.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_34.set_index('Rank', inplace = True)
LL34 = LL_34[LL_34.Name != 'Total / Average']
LL34.set_index('Name', inplace = True)
LL34['League'] = 'LaLiga'
LL34['Season'] = '13/14'
LL34
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                     Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Alfonso Javier Álvarez Izquierdo             22     28.86          0.72
# Carlos Clos Gómez                            22     26.95          0.63
# David José Fernández Borbalán                22     28.00          0.66
# ...

# %%
LL_23 = pd.read_csv('LaLiga_12_13.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_23.set_index('Rank', inplace = True)
LL23 = LL_23[LL_23.Name != 'Total / Average']
LL23.set_index('Name', inplace = True)
LL23['League'] = 'LaLiga'
LL23['Season'] = '12/13'
LL23
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                     Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Fernando Teixeira Vitienes                   24     29.88          0.69
# Carlos del Cerro Grande                      22     28.27          0.65
# Carlos Clos Gómez                            22     27.27          0.65
# ...

# %%
LL_12 = pd.read_csv('LaLiga_11_12.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_12.set_index('Rank', inplace = True)
LL12 = LL_12[LL_12.Name != 'Total/Average']
LL12.set_index('Name', inplace = True)
LL12['League'] = 'LaLiga'
LL12['Season'] = '11/12'
LL12
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                   Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Ignacio Iglesias Villanueva                22     29.14          0.62
# Javier Estrada Fernández                   22     28.05          0.60
# José Luis González González                22     26.09          0.57
# ...

# %%
LL_11 = pd.read_csv('LaLiga_10_11.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_11.set_index('Rank', inplace = True)
LL11 = LL_11[LL_11.Name != 'Total / Average']
LL11.set_index('Name', inplace = True)
LL11['League'] = 'LaLiga'
LL11['Season'] = '10/11'
LL11
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                   Appearances  Fouls PG  Fouls/Tackle  \
# Name
# César Muñiz Fernández                      24     30.42          0.72
# Javier Turienzo Alvarez                    22     28.23          0.70
# Alfonso Javier Álvarez Izquierdo           21     31.38          0.79
# ...

# %%
LL_91 = pd.read_csv('LaLiga_09_10.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
LL_91.set_index('Rank', inplace = True)
LL91 = LL_91[LL_91.Name != 'Total/Average']
LL91.set_index('Name', inplace = True)
LL91['League'] = 'LaLiga'
LL91['Season'] = '09/10'
LL91
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                   Appearances  Fouls PG  Fouls/Tackle  \
# Name
# Eduardo Iturralde González                 22     33.18          0.87
# Javier Estrada Fernández                   21     29.24          0.70
# Carlos Delgado Ferreiro                    20     31.40          0.78
# ...

# %%
B78 = pd.read_csv('Bundesliga_17_18.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B78_a = pd.read_csv('Bundesliga78_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_78 = pd.concat([B78, B78_a])
B_78.set_index('Rank', inplace = True)
B78 = B_78[B_78.Name != 'Total / Average']
B78.set_index('Name', inplace = True)
B78['League'] = 'Bundesliga'
B78['Season'] = '17/18'
B78
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Manuel Gräfe                18     20.44          0.51        0.11       2.33
# Deniz Aytekin               17     29.53          0.77        0.47       3.88
# ...

# %%
B67 = pd.read_csv('Bundesliga_16_17.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B67_a = pd.read_csv('Bundesliga67_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_67 = pd.concat([B67, B67_a])
B_67.set_index('Rank', inplace = True)
B67 = B_67[B_67.Name != 'Total / Average']
B67.set_index('Name', inplace = True)
B67['League'] = 'Bundesliga'
B67['Season'] = '16/17'
B67
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Dr. Felix Brych             18     28.28          0.68        0.61       4.72
# Manuel Gräfe                18     24.67          0.61        0.28       3.50
# ...

# %%
B56 = pd.read_csv('Bundesliga_15_16.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B56_a = pd.read_csv('Bundesliga56_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_56 = pd.concat([B56, B56_a])
B_56.set_index('Rank', inplace = True)
B56 = B_56[B_56.Name != 'Total / Average']
B56.set_index('Name', inplace = True)
B56['League'] = 'Bundesliga'
B56['Season'] = '15/16'
B56
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Dr. Felix Brych             19     27.89          0.80        0.11       3.95
# Felix Zwayer                18     30.50          0.83        0.28       4.72
# ...

# %%
B45 = pd.read_csv('Bundesliga_14_15.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B45_a = pd.read_csv('Bundesliga45_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_45 = pd.concat([B45, B45_a])
B_45.set_index('Rank', inplace = True)
B45 = B_45[B_45.Name != 'Total / Average']
B45.set_index('Name', inplace = True)
B45['League'] = 'Bundesliga'
B45['Season'] = '14/15'
B45
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Felix Zwayer                17     28.94          0.77        0.12       4.06
# Wolfgang Stark              17     31.00          0.75        0.29       3.71
# ...

# %%
B34 = pd.read_csv('Bundesliga_13_14.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B34_a = pd.read_csv('Bundesliga34_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_34 = pd.concat([B34, B34_a])
B_34.set_index('Rank', inplace = True)
B34 = B_34[B_34.Name != 'Total / Average']
B34.set_index('Name', inplace = True)
B34['League'] = 'Bundesliga'
B34['Season'] = '13/14'
B34
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Knut Kircher                16     29.06          0.73        0.19       3.06
# Felix Zwayer                16     28.19          0.72        0.25       3.56
# ...

# %%
B23 = pd.read_csv('Bundesliga_12_13.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B23_a = pd.read_csv('Bundesliga23_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_23 = pd.concat([B23, B23_a])
B_23.set_index('Rank', inplace = True)
B23 = B_23[B_23.Name != 'Total / Average']
B23.set_index('Name', inplace = True)
B23['League'] = 'Bundesliga'
B23['Season'] = '12/13'
B23
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Dr. Felix Brych             18     30.72          0.61        0.33       3.44
# Knut Kircher                17     30.35          0.61        0.24       3.18
# ...

# %%
B12 = pd.read_csv('Bundesliga_11_12.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B12_a = pd.read_csv('Bundesliga12_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_12 = pd.concat([B12, B12_a])
B_12.set_index('Rank', inplace = True)
B12 = B_12[B_12.Name != 'Total / Average']
B12.set_index('Name', inplace = True)
B12['League'] = 'Bundesliga'
B12['Season'] = '11/12'
B12
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Dr. Felix Brych             19     29.11          0.66        0.16       2.95
# Florian Meyer               19     36.21          0.88        0.21       3.11
# ...

# %%
B11 = pd.read_csv('Bundesliga_10_11.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B11_a = pd.read_csv('Bundesliga11_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_11 = pd.concat([B11, B11_a])
B_11.set_index('Rank', inplace = True)
B11 = B_78[B_78.Name != 'Total / Average']
B11.set_index('Name', inplace = True)
B11['League'] = 'Bundesliga'
B11['Season'] = '10/11'
B11
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Manuel Gräfe                18     20.44          0.51        0.11       2.33
# Deniz Aytekin               17     29.53          0.77        0.47       3.88
# ...

# %%
B91 = pd.read_csv('Bundesliga_09_10.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B91_a = pd.read_csv('Bundesliga09_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
B_09 = pd.concat([B91, B91_a])
B_09.set_index('Rank', inplace = True)
B09 = B_09[B_09.Name != 'Total / Average']
B09.set_index('Name', inplace = True)
B09['League'] = 'Bundesliga'
B09['Season'] = '09/10'
B09
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Wolfgang Stark                 21     29.76          0.69        0.24
# Knut Kircher                   20     34.30          0.77        0.15
# Dr. Felix Brych                20     31.75          0.74        0.45
# ...

# %%
L_78 = pd.read_csv('Ligue_1_17_18.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_78_a = pd.read_csv('L178_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_78 = pd.concat([L_78, L_78_a])
L_78.set_index('Rank', inplace = True)
L78 = L_78[L_78.Name != 'Total / Average']
L78.set_index('Name', inplace = True)
L78['League'] = 'Ligue 1'
L78['Season'] = '17/18'
L78
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# François Letexier            24     26.38          0.72        0.42
# Mikael Lesage                23     23.83          0.63        0.09
# Antony Gautier               23     28.78          0.82        0.26
# ...

# %%
L_67 = pd.read_csv('Ligue_1_16_17.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_67_a = pd.read_csv('L167_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_67 = pd.concat([L_67, L_67_a])
L_67.set_index('Rank', inplace = True)
L67 = L_67[L_67.Name != 'Total / Average']
L67.set_index('Name', inplace = True)
L67['League'] = 'Ligue 1'
L67['Season'] = '16/17'
L67
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Mikael Lesage                25     23.76          0.65        0.36
# Ruddy Buquet                 24     26.33          0.72        0.38
# Johan Hamel                  22     26.00          0.72        0.50
# ...

# %%
L_56 = pd.read_csv('Ligue_1_15_16.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_56_a = pd.read_csv('L156_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_56 = pd.concat([L_56, L_56_a])
L_56.set_index('Rank', inplace = True)
L56 = L_56[L_56.Name != 'Total / Average']
L56.set_index('Name', inplace = True)
L56['League'] = 'Ligue 1'
L56['Season'] = '15/16'
L56
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Benoît Millot                23     25.22          0.62        0.22
# Lionel Jaffredo              21     32.05          0.82        0.19
# Sébastien Moreira            20     27.65          0.74        0.40
# ...

# %%
L_45 = pd.read_csv('Ligue_1_14_15.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_45_a = pd.read_csv('L145_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_45 = pd.concat([L_45, L_45_a])
L_45.set_index('Rank', inplace = True)
L45 = L_45[L_45.Name != 'Total / Average']
L45.set_index('Name', inplace = True)
L45['League'] = 'Ligue 1'
L45['Season'] = '14/15'
L45
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Fredy Fautrel               22     28.86          0.75        0.32       4.27
# Benoît Bastien              20     26.90          0.66        0.40       3.45
# ...

# %%
L_34 = pd.read_csv('Ligue_1_13_14.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_34_a = pd.read_csv('L134_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_34 = pd.concat([L_34, L_34_a])
L_34.set_index('Rank', inplace = True)
L34 = L_34[L_34.Name != 'Total / Average']
L34.set_index('Name', inplace = True)
L34['League'] = 'Ligue 1'
L34['Season'] = '13/14'
L34
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                    Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Laurent Duhamel             21     27.00          0.68        0.14       2.14
# Ruddy Buquet                20     26.10          0.70        0.20       3.90
# ...

# %%
L_23 = pd.read_csv('Ligue_1_12_13.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_23_a = pd.read_csv('L123_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_23 = pd.concat([L_23, L_23_a])
L_23.set_index('Rank', inplace = True)
L23 = L_23[L_23.Name != 'Total / Average']
L23.set_index('Name', inplace = True)
L23['League'] = 'Ligue 1'
L23['Season'] = '12/13'
L23
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Clément Turpin                  21     28.71          0.70        0.14
# Said Ennjimi                    21     28.05          0.75        0.19
# ...

# %%
L_12 = pd.read_csv('Ligue_1_11_12.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_12_a = pd.read_csv('L112_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_12 = pd.concat([L_12, L_12_a])
L_12.set_index('Rank', inplace = True)
L12 = L_12[L_12.Name != 'Total / Average']
L12.set_index('Name', inplace = True)
L12['League'] = 'Ligue 1'
L12['Season'] = '12/13'
L12
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                        Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Antony Gautier                  19     30.37          0.80        0.32
# Lionel Jaffredo                 18     34.56          0.91        0.17
# ...

# %%
L_11 = pd.read_csv('Ligue_1_10_11.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_11_a = pd.read_csv('L101_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_11 = pd.concat([L_11, L_11_a])
L_11.set_index('Rank', inplace = True)
L11 = L_11[L_11.Name != 'Total / Average']
L11.set_index('Name', inplace = True)
L11['League'] = 'Ligue 1'
L11['Season'] = '10/11'
L11
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Stéphane Lannoy                  19     32.95          0.87        0.16
# Antony Gautier                   19     29.79          0.83        0.32
# ...

# %%
L_90 = pd.read_csv('Ligue_1_09_10.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_90_a = pd.read_csv('L190_a.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
L_90 = pd.concat([L_90, L_90_a])
L_90.set_index('Rank', inplace = True)
L90 = L_90[L_90.Name != 'Total / Average']
L90.set_index('Name', inplace = True)
L90['League'] = 'Ligue 1'
L90['Season'] = '09/10'
L90
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Lionel Jaffredo              20     36.95          1.03        0.25
# Ruddy Buquet                 20     32.25          0.83        0.10
# Pascal Vileo                 20     35.45          0.84        0.25
# ...

# %%
PL_78 = pd.read_csv('PL78.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_78.set_index('Rank', inplace = True)
PL78 = PL_78[PL_78.Name != 'Total / Average']
PL78.set_index('Name', inplace = True)
PL78['League'] = 'Premier League'
PL78['Season'] = '17/18'
PL78
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Michael Oliver            30     22.40          0.68        0.27       3.33
# Jonathan Moss             29     21.93          0.68        0.31       3.69
# ...

# %%
PL_67 = pd.read_csv('PL_16_17.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_67.set_index('Rank', inplace = True)
PL67 = PL_67[PL_67.Name != 'Total / Average']
PL67.set_index('Name', inplace = True)
PL67['League'] = 'Premier League'
PL67['Season'] = '16/17'
PL67
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Michael Oliver             33     21.61          0.56        0.48       3.36
# Mike Dean                  30     22.47          0.63        0.43       3.70
# ...

# %%
PL_56 = pd.read_csv('PL_15_16.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_56.set_index('Rank', inplace = True)
PL56 = PL_56[PL_56.Name != 'Total / Average']
PL56.set_index('Name', inplace = True)
PL56['League'] = 'Premier League'
PL56['Season'] = '15/16'
PL56
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Mike Dean                  33     21.85          0.59        0.39       3.24
# Anthony Taylor             31     21.06          0.54        0.23       3.45
# ...

# %%
PL_45 = pd.read_csv('PL_14_15.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_45.set_index('Rank', inplace = True)
PL45 = PL_45[PL_45.Name != 'Total/Average']
PL45.set_index('Name', inplace = True)
PL45['League'] = 'Premier League'
PL45['Season'] = '14/15'
PL45
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Martin Atkinson            31     21.81          0.52        0.23       3.77
# Jonathan Moss              30     23.17          0.63        0.30       3.63
# ...

# %%
PL_34 = pd.read_csv('PL_13_14.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_34.set_index('Rank', inplace = True)
PL34 = PL_34[PL_34.Name != 'Total / Average']
PL34.set_index('Name', inplace = True)
PL34['League'] = 'Premier League'
PL34['Season'] = '13/14'
PL34
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Howard Webb                31     21.35          0.55        0.10       2.97
# Mike Dean                  27     22.33          0.63        0.26       3.67
# ...

# %%
PL_23 = pd.read_csv('PL_12_13.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_23.set_index('Rank', inplace = True)
PL23 = PL_23[PL_23.Name != 'Total / Average']
PL23.set_index('Name', inplace = True)
PL23['League'] = 'Premier League'
PL23['Season'] = '12/13'
PL23
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Howard Webb                30     22.43          0.57        0.20       3.63
# Mike Dean                  28     23.79          0.62        0.18       3.64
# ...

# %%
PL_12 = pd.read_csv('PL_11_12.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_12.set_index('Rank', inplace = True)
PL12 = PL_12[PL_12.Name != 'Total / Average']
PL12.set_index('Name', inplace = True)
PL12['League'] = 'Premier League'
PL12['Season'] = '11/12'
PL12
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Mike Dean                  30     20.30          0.48        0.40       3.60
# Howard Webb                29     21.90          0.55        0.24       3.03
# ...

# %%
PL_11 = pd.read_csv('PL_10_11.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_11.set_index('Rank', inplace = True)
PL11 = PL_11[PL_11.Name != 'Total / Average']
PL11.set_index('Name', inplace = True)
PL11['League'] = 'Premier League'
PL11['Season'] = '10/11'
PL11
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Mike Dean                  30     21.47          0.49        0.37       3.43
# Phil Dowd                  30     26.13          0.72        0.27       3.60
# ...

# %%
PL_90 = pd.read_csv('PL_09_10.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
PL_90.set_index('Rank', inplace = True)
PL90 = PL_90[PL_90.Name != 'Total / Average']
PL90.set_index('Name', inplace = True)
PL90['League'] = 'Premier League'
PL90['Season'] = '09/10'
PL90
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                   Appearances  Fouls PG  Fouls/Tackle  Penalty PG  Yellow PG  \
# Name
# Martin Atkinson            31     29.00          0.69        0.32       3.97
# Mark Clattenburg           31     24.52          0.54        0.29       2.55
# ...

# %%
SA_78 = pd.read_csv('SA78.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_78.set_index('Rank', inplace = True)
SA78 = SA_78[SA_78.Name != 'Total / Average']
SA78.set_index('Name', inplace = True)
SA78['League'] = 'Serie A'
SA78['Season'] = '17/18'
SA78
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Davide Massa                     19     26.63          0.83        0.32
# Luca Banti                       18     19.67          0.58        0.28
# Paolo Silvio Mazzoleni           18     24.50          0.77        0.33
# ...

# %%
SA_67 = pd.read_csv('SA67.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_67.set_index('Rank', inplace = True)
SA67 = SA_67[SA_67.Name != 'Total / Average']
SA67.set_index('Name', inplace = True)
SA67['League'] = 'Serie A'
SA67['Season'] = '16/17'
SA67
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Paolo Valeri                     17     28.47          0.85        0.35
# Maurizio Mariani                 17     27.12          0.84        0.53
# Paolo Silvio Mazzoleni           17     31.59          0.90        0.41
# ...

# %%
SA_56 = pd.read_csv('SA56.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_56.set_index('Rank', inplace = True)
SA56 = SA_56[SA_56.Name != 'Total / Average']
SA56.set_index('Name', inplace = True)
SA56['League'] = 'Serie A'
SA56['Season'] = '15/16'
SA56
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Andrea Gervasoni                 19     26.84          0.74        0.32
# Domenico Celi                    18     24.39          0.75        0.22
# Gianluca Rocchi                  18     31.89          0.88        0.78
# ...

# %%
SA_45 = pd.read_csv('SA45.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_45.set_index('Rank', inplace = True)
SA45 = SA_45[SA_45.Name != 'Total / Average']
SA45.set_index('Name', inplace = True)
SA45['League'] = 'Serie A'
SA45['Season'] = '14/15'
SA45
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Luca Banti                       20     25.50          0.72        0.40
# Massimiliano Irrati              19     28.68          0.85        0.21
# Paolo Silvio Mazzoleni           18     32.44          0.88        0.22
# ...

# %%
SA_34 = pd.read_csv('SA34.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_34.set_index('Rank', inplace = True)
SA34 = SA_34[SA_34.Name != 'Total / Average']
SA34.set_index('Name', inplace = True)
SA34['League'] = 'Serie A'
SA34['Season'] = '13/14'
SA34
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Daniele Orsato                   18     31.17          0.71        0.28
# Paolo Silvio Mazzoleni           18     33.78          0.88        0.44
# Gianluca Rocchi                  18     28.83          0.72        0.56
# ...

# %%
SA_23 = pd.read_csv('SA23.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_23.set_index('Rank', inplace = True)
SA23 = SA_23[SA_23.Name != 'Total / Average']
SA23.set_index('Name', inplace = True)
SA23['League'] = 'Serie A'
SA23['Season'] = '12/13'
SA23
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Gianluca Rocchi                  19     32.00          0.67        0.42
# Antonio Giannoccaro              19     34.63          0.75        0.47
# Daniele Orsato                   18     28.17          0.57        0.17
# ...

# %%
SA_12 = pd.read_csv('SA12.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_12.set_index('Rank', inplace = True)
SA12 = SA_12[SA_12.Name != 'Total / Average']
SA12.set_index('Name', inplace = True)
SA12['League'] = 'Serie A'
SA12['Season'] = '11/12'
SA12
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                          Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Domenico Celi                     19     27.16          0.61        0.32
# Luca Banti                        19     30.58          0.68        0.16
# ...

# %%
SA_11 = pd.read_csv('SA11.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_11.set_index('Rank', inplace = True)
SA11 = SA_11[SA_11.Name != 'Total / Average']
SA11.set_index('Name', inplace = True)
SA11['League'] = 'Serie A'
SA11['Season'] = '10/11'
SA11
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Paolo Tagliavento                20     31.25          0.78        0.40
# Nicola Rizzoli                   20     30.35          0.71        0.40
# Gianluca Rocchi                  19     28.47          0.67        0.32
# ...

# %%
SA_09 = pd.read_csv('SA09.csv', names = ['Rank', 'Name', 'Appearances', 'Fouls PG', 'Fouls/Tackle', 'Penalty PG', 'Yellow PG', 'Yellow Cards', 'Red PG', 'Red Cards'])
SA_09.set_index('Rank', inplace = True)
SA09 = SA_09[SA_09.Name != 'Total / Average']
SA09.set_index('Name', inplace = True)
SA09['League'] = 'Serie A'
SA09['Season'] = '09/10'
SA09
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                          Appearances  Fouls PG  Fouls/Tackle  Penalty PG  \
# Name
# Paolo Tagliavento                 22     32.73          0.83        0.50
# Mauro Bergonzi                    21     35.38          0.88        0.24
# ...
